# %%
#Import module yang dibutuhkan

import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import skew
import seaborn as sns
import numpy as np

# %%
#Import Data

df = pd.read_csv('https://raw.githubusercontent.com/adawiaan/Test/main/DATASET%20UAS%20MOLIN%20FIX%20.csv')
df.head()
# Out:
#          AREA  INT_SQFT  REG_FEE  SALES_PRICE
# 0  Anna Nagar      1628   331348     10688640
# 1     T Nagar      1584   370363     11573840
# 2   Velachery      1971   591269     15559710
# 3    KK Nagar      2399   637030     14156220
# 4    KK Nagar      1741   366038     10458220

# %%
#Statistik dari Dataset

df.describe(include='all')
# Out:
#             AREA     INT_SQFT        REG_FEE   SALES_PRICE
# count        281   281.000000     281.000000  2.810000e+02
# unique         7          NaN            NaN           NaN
# top     Chrompet          NaN            NaN           NaN
# freq          72          NaN            NaN           NaN
# mean         NaN  1359.693950  367992.149466  1.066606e+07
# std          NaN   464.843421  123569.183482  3.241106e+06
# min          NaN   517.000000  134508.000000  3.785500e+06
# 25%          NaN  1008.000000  271920.000000  8.371810e+06
# 50%          NaN  1287.000000  344772.000000  1.026245e+07
# 75%          NaN  1707.000000  444970.000000  1.274669e+07
# max          NaN  2483.000000  695964.000000  1.897681e+07

# %%
#Pair plot antar variabel

sns.pairplot(df)

# %%
#Heatmap antar variabel

plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True)

# %%
plt.figure(figsize=(16,5))

plt.subplot(1,2,1)
sns.histplot(df["INT_SQFT"], kde=True)

plt.subplot(1,2,2)
sns.histplot(df["REG_FEE"], kde=True)

plt.show()
